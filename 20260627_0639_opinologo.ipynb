# %% [markdown]
# <a href="https://colab.research.google.com/github/agmCorp/opinologo/blob/main/20260627_0639_opinologo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Opinólogo
# ### Motor de Argumentacion Formal sobre LLMs
#
# **Opinólogo** convierte cualquier pregunta controversial en un analisis argumentativo formal,
# produciendo una conclusion *justificada* (o *refutada*) con trazabilidad completa.
#
# ---
#
# ### Como funciona?
#
# | Paso | Componente | Que hace |
# |------|-----------|----------|
# | 1 | **C1 -- Generador** | LLM produce argumentos PRO en Lenguaje Natural Controlado (CNL) |
# | 2 | **C2 -- Abogado del Diablo** | Mismo LLM, rol diferente: genera los mejores ataques posibles |
# | 3 | **Loop adversarial** | C1 y C2 se alternan N rondas construyendo el grafo de argumentos |
# | 4 | **C3 -- Parser CNL** | Convierte texto semi-estructurado a estructuras formales ASPIC+ |
# | 5 | **C4 -- Motor Dung** | Calcula la *grounded extension*: que argumentos sobreviven todos los ataques |
# | 6 | **C5 -- Narrador** | Traduce el resultado formal a una explicacion en lenguaje natural trazable |
#
# ---
#
# ### Arquitectura
#
# ```
#             [Pregunta]
#                 |
#                 v
# +---------------------------------+
# |  C1: Generador                  |  LLM - argumentos PRO en CNL (IDs: A1, A2, ...)
# +---------------+-----------------+
#                 | loop adversarial (max N rondas)
#                 v
# +---------------------------------+
# |  C2: Abogado del Diablo         |  LLM - ataques + contra-args en CNL (IDs: B1, B2, ...)
# +---------------+-----------------+
#                 |
#                 v
# +---------------------------------+
# |  C3: Parser CNL -> ASPIC+       |  Deterministico - texto -> estructuras formales
# +---------------+-----------------+
#                 |
#                 v
# +---------------------------------+
# |  C4: Motor ASPIC+/Dung          |  Deterministico - computa grounded extension
# +---------------+-----------------+
#                 |
#                 v
# +---------------------------------+
# |  C5: Narrador                   |  LLM - explicacion trazable en lenguaje natural
# +---------------+-----------------+
#                 |
#                 v
# [Conclusion + arbol de argumentos + grafo JSON]
# ```
#
# ---
#
# ### Lenguaje Natural Controlado (CNL)
#
# ```
# # Argumento defeasible (rebatible -- usar por defecto)
# ARG A1: "premisa1", "premisa2" => "conclusion"
#
# # Argumento estricto (logicamente necesario)
# ARG A2: "premisa1" -> "conclusion"
#
# # Con excepcion explicita
# ARG A3: "premisa1" => "conclusion" SALVO "excepcion"
#
# # Rebuttal: A contradice la conclusion de B
# A1 REFUTA B1
#
# # Undercut: A invalida la regla defeasible de B
# A2 SOCAVA B2
#
# # Conclusion que se defiende
# CONCLUSION: "texto de la conclusion"
# ```

# %% [markdown]
# ## Paso 1 -- Instalacion
#
# Ejecuta esta celda **una sola vez** al inicio de la sesion Colab.
# Luego ejecuta **Runtime > Ejecutar todo** (Ctrl+F9) para cargar todos los modulos.

# %%
# Dependencias para todos los proveedores en la nube
# !pip install -q openai google-genai anthropic huggingface_hub

# Dependencias adicionales para HuggingFaceLocalClient (Opcion F - GPU local)
# Solo necesaria si vas a usar modelos locales en Colab con GPU T4/A100.
# !pip install -q transformers bitsandbytes accelerate

print("Dependencias instaladas.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 932.0/932.0 kB 21.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 13.7 MB/s eta 0:00:00
# Dependencias instaladas.

# %% [markdown]
# ## Modulo 1 -- Estructuras de Datos
#
# Define los tipos de datos centrales del sistema ASPIC+/Dung.
#
# | Clase | Descripcion |
# |-------|-------------|
# | `Argument` | Un argumento formal: premisas + conclusion + tipo de regla |
# | `Attack` | Relacion de ataque entre dos argumentos (rebuttal o undercut) |
# | `ArgumentGraph` | El grafo completo acumulado durante el loop adversarial |
# | `EvaluationResult` | Resultado del motor Dung: que argumentos sobrevivieron |
# | `PipelineResult` | Resultado final completo: grafo + evaluacion + explicacion |

# %%
from __future__ import annotations
from dataclasses import dataclass, field
from typing import Literal


@dataclass
class Argument:
    # Argumento formal en ASPIC+.
    # id:         identificador unico, ej: "A1", "B3"
    # premises:   lista de premisas en lenguaje natural
    # conclusion: lo que se infiere de las premisas
    # rule_type:  "defeasible" (=>) rebatible por defecto
    #             "strict"    (->) inferencia logicamente necesaria
    # exception:  excepcion explicita (clausula SALVO), si aplica
    # stance:     "pro" (defiende la tesis) | "con" (la ataca).
    #             Lo asigna el codigo segun el componente que crea el
    #             argumento (Generador=pro, Diablo=con); NO lo infiere
    #             el LLM ni el prefijo del ID.
    id: str
    premises: list[str]
    conclusion: str
    rule_type: Literal["strict", "defeasible"]
    exception: str | None = None
    stance: Literal["pro", "con"] = "pro"


@dataclass
class Attack:
    # Relacion de ataque entre dos argumentos.
    # attacker_id: ID del argumento que ataca
    # target_id:   ID del argumento atacado
    # attack_type: "rebuttal" (REFUTA) = conclusion contradice conclusion del objetivo
    #              "undercut" (SOCAVA) = invalida la regla defeasible del objetivo
    attacker_id: str
    target_id: str
    attack_type: Literal["rebuttal", "undercut"]


@dataclass
class ArgumentGraph:
    # Grafo de argumentacion completo.
    # Acumula todos los argumentos y ataques generados durante el loop adversarial.
    # to_cnl() lo serializa para pasarlo como contexto al LLM.
    arguments: dict[str, Argument] = field(default_factory=dict)
    attacks: list[Attack] = field(default_factory=list)
    target_conclusion: str = ""

    def to_cnl(self) -> str:
        lines = []
        for arg in self.arguments.values():
            premises_str = ", ".join(f'"{p}"' for p in arg.premises)
            arrow = "->" if arg.rule_type == "strict" else "=>"
            line = f'ARG {arg.id}: {premises_str} {arrow} "{arg.conclusion}"'
            if arg.exception:
                line += f' SALVO "{arg.exception}"'
            lines.append(line)
        for attack in self.attacks:
            verb = "REFUTA" if attack.attack_type == "rebuttal" else "SOCAVA"
            lines.append(f"{attack.attacker_id} {verb} {attack.target_id}")
        if self.target_conclusion:
            lines.append(f'CONCLUSION: "{self.target_conclusion}"')
        return "\n".join(lines)


@dataclass
class EvaluationResult:
    # Resultado de la evaluacion formal (semantica de Dung).
    conclusion: str
    justified: bool
    supporting_argument_id: str | None
    grounded_extension: list[str]
    defeated: list[str]
    undecidable: list[str]


@dataclass
class PipelineResult:
    # Resultado completo del pipeline.
    explanation: str
    graph: ArgumentGraph
    evaluation: EvaluationResult


print("Modulo 1 OK: Argument, Attack, ArgumentGraph, EvaluationResult, PipelineResult")
# Out:
# Modulo 1 OK: Argument, Attack, ArgumentGraph, EvaluationResult, PipelineResult

# %% [markdown]
# ## Modulo 2 -- Parser CNL -> ASPIC+
#
# Convierte texto CNL (generado por el LLM) a estructuras de datos formales.
# Lineas que no coinciden con ningun patron se ignoran silenciosamente.

# %%
import re

_ARG_RE = re.compile(
    r'ARG\s+(\w+)\s*:\s*((?:"[^"]*",?\s*)+)[-=]>\s*"([^"]*)"'
)
_EXCEPT_RE   = re.compile(r'SALVO\s+"([^"]*)"')
_ATTACK_RE   = re.compile(r'(\w+)\s+(REFUTA|SOCAVA)\s+(\w+)')
_CONCL_RE    = re.compile(r'CONCLU(?:SI[OO]N|SION)\s*:\s*"?([^"\n]+)"?')


def _normalize_text(s: str) -> str:
    # Normaliza para comparar conclusiones/excepciones: colapsa espacios,
    # comillas y puntuacion, y pasa a minusculas. Permite emparejar
    # variantes tipograficas de un mismo enunciado.
    return re.sub(r'[\s"\'.,;:!¡¿?]+', ' ', s).strip().casefold()


def parse_cnl_block(block: str) -> tuple[list, list, str | None]:
    # Parsea un bloque CNL y devuelve (argumentos, ataques, conclusion_o_None).
    arguments: list[Argument] = []
    attacks: list[Attack] = []
    conclusion: str | None = None

    for line in block.splitlines():
        line = line.strip()

        m = _ARG_RE.match(line)
        if m:
            arg_id       = m.group(1)
            raw_premises = m.group(2)
            concl_text   = m.group(3)
            premises     = re.findall(r'"([^"]*)"', raw_premises)
            rule_type    = "strict" if ("->" in line and "=>" not in line) else "defeasible"
            exception    = None
            exc_m = _EXCEPT_RE.search(line)
            if exc_m:
                exception = exc_m.group(1)
            arguments.append(Argument(
                id=arg_id, premises=premises, conclusion=concl_text,
                rule_type=rule_type, exception=exception,
            ))
            continue

        m = _ATTACK_RE.match(line)
        if m:
            attacker, verb, target = m.group(1), m.group(2), m.group(3)
            attacks.append(Attack(
                attacker_id=attacker,
                target_id=target,
                attack_type="rebuttal" if verb == "REFUTA" else "undercut",
            ))
            continue

        m = _CONCL_RE.match(line)
        if m:
            conclusion = m.group(1).strip().strip('"')

    return arguments, attacks, conclusion


def validate_block(block: str, known_ids: set) -> list[str]:
    errors: list[str] = []
    for line in block.splitlines():
        line = line.strip()
        if line.count('"') % 2 != 0:
            errors.append(f"Comilla sin cerrar: {line[:60]}")
        m = _ATTACK_RE.match(line)
        if m and known_ids:
            attacker, target = m.group(1), m.group(3)
            if attacker not in known_ids:
                errors.append(f"ID atacante desconocido: {attacker}")
            if target not in known_ids:
                errors.append(f"ID objetivo desconocido: {target}")
    return errors


def extract_tagged_block(raw: str, tag: str) -> str:
    open_tag, close_tag = f"<{tag}>", f"</{tag}>"
    start = raw.find(open_tag)
    end   = raw.find(close_tag)
    if start == -1 or end == -1:
        return raw
    return raw[start + len(open_tag):end].strip()


print("Modulo 2 OK: parse_cnl_block, validate_block, extract_tagged_block, _normalize_text")
# Out:
# Modulo 2 OK: parse_cnl_block, validate_block, extract_tagged_block, _normalize_text

# %% [markdown]
# ## Modulo 3 -- Motor de Argumentacion (Semantica de Dung)
#
# Implementa el algoritmo de **grounded extension** de Dung (1995).
#
# Un argumento se acepta si todos sus atacantes estan rechazados.
# Un argumento se rechaza si al menos un atacante esta aceptado.
# Si ninguna condicion aplica: indecidible (empate genuino).

# %%
from __future__ import annotations


def compute_defeats(graph: ArgumentGraph) -> dict[str, set[str]]:
    # Baja la estructura ASPIC+ (rule_type, attack_type, exception) a una
    # relacion de derrota efectiva: target_id -> {ids que lo derrotan}.
    #   - SOCAVA (undercut): unidireccional; solo contra reglas defeasible.
    #   - REFUTA (rebuttal): simetrico, modulado por strict > defeasible.
    #   - SALVO (exception): undercut sintetico si otro arg concluye la excepcion.
    args = graph.arguments
    defeaters: dict[str, set[str]] = {id_: set() for id_ in args}

    def is_strict(arg_id: str) -> bool:
        return args[arg_id].rule_type == "strict"

    for atk in graph.attacks:
        x, y = atk.attacker_id, atk.target_id
        if x not in args or y not in args:
            continue
        if atk.attack_type == "undercut":
            if not is_strict(y):
                defeaters[y].add(x)
        else:  # rebuttal: simetrico, modulado por strict > defeasible
            xs, ys = is_strict(x), is_strict(y)
            if not xs and not ys:
                defeaters[y].add(x)
                defeaters[x].add(y)
            elif xs and not ys:
                defeaters[y].add(x)
            elif ys and not xs:
                defeaters[x].add(y)
            # ambos estrictos -> se descarta (inconsistencia)

    # SALVO: si otro argumento concluye la excepcion, la regla queda socavada.
    # No aplica a reglas estrictas (una regla estricta no tiene excepcion que socavar).
    for y_id, y in args.items():
        if y.exception and not is_strict(y_id):
            e_norm = _normalize_text(y.exception)
            for z_id, z in args.items():
                if z_id != y_id and _normalize_text(z.conclusion) == e_norm:
                    defeaters[y_id].add(z_id)

    return defeaters


def grounded_extension(graph: ArgumentGraph) -> EvaluationResult:
    # Computa la grounded extension sobre la relacion de derrota ASPIC+
    # (no sobre los ataques crudos). Punto fijo monotonico O(n^2).
    all_ids = set(graph.arguments.keys())
    attackers = compute_defeats(graph)

    accepted: set[str] = set()
    rejected: set[str] = set()

    changed = True
    while changed:
        changed = False
        for arg_id in all_ids:
            if arg_id in accepted or arg_id in rejected:
                continue
            if all(a in rejected for a in attackers[arg_id]):
                accepted.add(arg_id)
                changed = True
        for arg_id in all_ids:
            if arg_id in accepted or arg_id in rejected:
                continue
            if any(a in accepted for a in attackers[arg_id]):
                rejected.add(arg_id)
                changed = True

    undecidable = sorted(all_ids - accepted - rejected)

    # Veredicto por stance: un argumento PRO aceptado cuya conclusion coincide
    # (normalizada) con la tesis. Sin fallback por prefijo de ID.
    target_norm = _normalize_text(graph.target_conclusion)
    supporting_id: str | None = next(
        (id_ for id_ in sorted(accepted)
         if graph.arguments[id_].stance == "pro"
         and _normalize_text(graph.arguments[id_].conclusion) == target_norm),
        None,
    )

    return EvaluationResult(
        conclusion=graph.target_conclusion,
        justified=supporting_id is not None,
        supporting_argument_id=supporting_id,
        grounded_extension=sorted(accepted),
        defeated=sorted(rejected),
        undecidable=undecidable,
    )


def classify_nodes(graph: ArgumentGraph, result: EvaluationResult) -> dict[str, str]:
    # Mapea cada id de argumento a su estado: "in" / "out" / "undec".
    accepted = set(result.grounded_extension)
    rejected = set(result.defeated)
    states: dict[str, str] = {}
    for id_ in graph.arguments:
        if id_ in accepted:
            states[id_] = "in"
        elif id_ in rejected:
            states[id_] = "out"
        else:
            states[id_] = "undec"
    return states


print("Modulo 3 OK: compute_defeats, grounded_extension, classify_nodes")
# Out:
# Modulo 3 OK: compute_defeats, grounded_extension, classify_nodes

# %%
# Modulo 3b -- Tests de la semantica ASPIC+
# Verifica que rule_type, attack_type y exception realmente incidan.

def _mk_graph(args, attacks, target=""):
    return ArgumentGraph(
        arguments={a.id: a for a in args},
        attacks=attacks,
        target_conclusion=target,
    )

# (1) Parser reconoce reglas estrictas (->)
_a, _x, _c = parse_cnl_block('ARG A1: "p" -> "q"')
assert len(_a) == 1 and _a[0].rule_type == "strict", "parser debe reconocer ->"

# (1b) Normalizacion de texto
assert _normalize_text('  "Hola, Mundo." ') == _normalize_text("hola mundo")

# (1c) stance por defecto
assert Argument("A1", ["p"], "q", "defeasible").stance == "pro"

# (2) compute_defeats: estricto NO rebatible
_A = Argument("A1", ["p"], "q", "strict", stance="pro")
_B = Argument("B1", ["r"], "no q", "defeasible", stance="con")
_d = compute_defeats(_mk_graph([_A, _B], [Attack("B1", "A1", "rebuttal")]))
assert _d["A1"] == set() and _d["B1"] == {"A1"}, "estricto gana el rebuttal"

# (2b) rebuttal simetrico vs undercut unidireccional (dos defeasibles)
_A = Argument("A1", ["p"], "q", "defeasible", stance="pro")
_B = Argument("B1", ["r"], "no q", "defeasible", stance="con")
_d_reb = compute_defeats(_mk_graph([_A, _B], [Attack("B1", "A1", "rebuttal")]))
assert _d_reb["A1"] == {"B1"} and _d_reb["B1"] == {"A1"}, "rebuttal -> mutuo"
_d_unc = compute_defeats(_mk_graph([_A, _B], [Attack("B1", "A1", "undercut")]))
assert _d_unc["A1"] == {"B1"} and _d_unc["B1"] == set(), "undercut -> unidireccional"

# (2c) undercut contra estricto se descarta
_A = Argument("A1", ["p"], "q", "strict", stance="pro")
_d = compute_defeats(_mk_graph([_A, _B], [Attack("B1", "A1", "undercut")]))
assert _d["A1"] == set(), "no se puede socavar una regla estricta"

# (3) SALVO: dormido (sin efecto) vs activo (undercut sintetico)
_A = Argument("A1", ["p"], "q", "defeasible", exception="hay excepcion", stance="pro")
_d_dorm = compute_defeats(_mk_graph([_A], []))
assert _d_dorm["A1"] == set(), "SALVO dormido: sin efecto"
_Z = Argument("Z1", ["s"], "hay excepcion", "defeasible", stance="con")
_d_act = compute_defeats(_mk_graph([_A, _Z], []))
assert _d_act["A1"] == {"Z1"}, "SALVO activo: undercut sintetico desde Z1"

# (3c) SALVO no socava una regla estricta (aunque la excepcion este concluida)
_As = Argument("A1", ["p"], "q", "strict", exception="hay excepcion", stance="pro")
_Zs = Argument("Z1", ["s"], "hay excepcion", "defeasible", stance="con")
_d_str = compute_defeats(_mk_graph([_As, _Zs], []))
assert _d_str["A1"] == set(), "SALVO no debe socavar una regla estricta"

# (4) grounded_extension usa la relacion de derrota ASPIC+
_A = Argument("A1", ["p"], "q", "strict", stance="pro")
_B = Argument("B1", ["r"], "no q", "defeasible", stance="con")
_ev = grounded_extension(_mk_graph([_A, _B], [Attack("B1", "A1", "rebuttal")], target="q"))
assert "A1" in _ev.grounded_extension, "estricto sobrevive al rebuttal"
assert "B1" in _ev.defeated

# (4b) rebuttal mutuo entre defeasibles -> ambos UNDEC
_A = Argument("A1", ["p"], "q", "defeasible", stance="pro")
_B = Argument("B1", ["r"], "no q", "defeasible", stance="con")
_ev = grounded_extension(_mk_graph([_A, _B], [Attack("B1", "A1", "rebuttal")]))
assert _ev.undecidable == ["A1", "B1"], "rebuttal simetrico -> ambos UNDEC"

# (4c) reinstanciacion via undercuts unidireccionales
_A = Argument("A1", ["p"], "q", "defeasible", stance="pro")
_B = Argument("B1", ["r"], "no q", "defeasible", stance="con")
_C = Argument("C1", ["t"], "no r", "defeasible", stance="pro")
_ev = grounded_extension(_mk_graph(
    [_A, _B, _C],
    [Attack("C1", "B1", "undercut"), Attack("B1", "A1", "undercut")],
    target="q",
))
assert "C1" in _ev.grounded_extension and "B1" in _ev.defeated and "A1" in _ev.grounded_extension, "reinstanciacion"

# (5) Veredicto por stance (no por prefijo de ID)
_A = Argument("A1", ["p"], "q", "defeasible", stance="pro")
assert grounded_extension(_mk_graph([_A], [], target="q")).justified is True
_W = Argument("W9", ["p"], "q", "defeasible", stance="con")   # mismo texto, stance con
_evW = grounded_extension(_mk_graph([_W], [], target="q"))
assert _evW.justified is False and _evW.supporting_argument_id is None, "stance con no justifica"

# (5b) SALVO activo cambia el veredicto
_A = Argument("A1", ["p"], "q", "defeasible", exception="hay excepcion", stance="pro")
_Z = Argument("Z1", ["s"], "hay excepcion", "defeasible", stance="con")
_ev = grounded_extension(_mk_graph([_A, _Z], [], target="q"))
assert _ev.justified is False and "A1" in _ev.defeated, "SALVO activo derrota la tesis"

# (6) classify_nodes
_states = classify_nodes(_mk_graph([_A, _Z], []), _ev)
assert _states["A1"] == "out" and _states["Z1"] == "in"

print("Modulo 3b OK: ASPIC+ (strict, undercut/rebuttal, SALVO, reinstanciacion, veredicto, classify)")
# Out:
# Modulo 3b OK: ASPIC+ (strict, undercut/rebuttal, SALVO, reinstanciacion, veredicto, classify)

# %% [markdown]
# ## Modulo 4 -- Prompts de Sistema
#
# | Prompt | Rol | Proposito |
# |--------|-----|-----------|
# | `GENERATOR_SYSTEM` | C1 | Construir argumentos PRO en CNL |
# | `GENERATOR_INITIAL_TEMPLATE` | C1 | Primera llamada: generar desde cero |
# | `GENERATOR_RESPONSE_TEMPLATE` | C1 | Rondas siguientes: rebatir ataques del Diablo |
# | `DEVIL_SYSTEM` | C2 | Generar los mejores ataques posibles |
# | `DEVIL_TEMPLATE` | C2 | Cada invocacion del Abogado del Diablo |
# | `NARRATOR_SYSTEM` | C5 | Traducir el resultado formal a lenguaje natural |
# | `NARRATOR_TEMPLATE` | C5 | Cada invocacion del Narrador |

# %%
GENERATOR_SYSTEM = """You are an expert argumentation analyst. Construct the strongest arguments supporting a defensible conclusion.

Output format -- CNL (Controlled Natural Language):
  ARG [ID]: "[premise1]", "[premise2]" => "[conclusion]"   (defeasible, use by default)
  ARG [ID]: "[premise1]" -> "[conclusion]"                  (strict, only if logically necessary)
  ARG [ID]: "[premise1]" => "[conclusion]" SALVO "[exception]"
  CONCLUSION: "[the conclusion you defend]"

Rules:
- Use IDs A1, A2, A3, ... (never reuse an ID already in the graph)
- Premises and conclusions are affirmative statements in double quotes
- At most 5 premises per argument -- simpler arguments are stronger
- Generate 3-6 arguments
- End with CONCLUSION: "[conclusion]"
- Wrap output in <ARGUMENTOS>...</ARGUMENTOS> tags"""


GENERATOR_INITIAL_TEMPLATE = """Problem: {problem}

Generate arguments defending the most defensible conclusion."""


GENERATOR_RESPONSE_TEMPLATE = """Problem: {problem}

Current argument graph:
{current_graph}

Generate additional arguments to rebut the attacks (B-IDs) above. Continue the A-ID sequence from the graph.

CRITICAL: For each new argument that rebuts a B-argument, you MUST declare the attack:
  A_ID REFUTA B_ID   or   A_ID SOCAVA B_ID

Example:
  ARG A6: "studies show remote productivity matches office productivity" => "remote work does not reduce output"
  A6 REFUTA B3

Every new argument must be followed by the attack declaration it supports."""


DEVIL_SYSTEM = """You are a rigorous devil's advocate. Find the strongest possible attacks against the given arguments.

Output format -- same CNL rules as the generator, plus attack declarations:
  [ID_A] REFUTA [ID_B]    (rebuttal: A's conclusion contradicts B's)
  [ID_A] SOCAVA [ID_B]    (undercut: A attacks B's defeasible rule)

CRITICAL: Every argument you declare MUST be followed immediately by at least one attack declaration.
An argument with no REFUTA or SOCAVA line is invalid -- it has no effect on the graph.

Example of correct format:
  ARG B1: "remote work reduces face-to-face collaboration" => "remote work harms innovation"
  B1 REFUTA A2
  ARG B2: "enforcing office attendance increases commute stress" => "mandatory office return reduces productivity"
  B2 SOCAVA A1

Rules:
- New arguments use IDs B1, B2, ... continuing from existing B-IDs in the graph
- If you cannot find any new meaningful attacks, output only: SIN_NUEVOS_ATAQUES
- Wrap output in <ATAQUES>...</ATAQUES> tags"""


DEVIL_TEMPLATE = """Problem: {problem}

Current argument graph:
{current_graph}

Generate the strongest possible attacks against the pro-conclusion arguments (those with A-IDs).
For EACH new argument you create, you MUST declare which existing argument it attacks using REFUTA or SOCAVA."""


NARRATOR_SYSTEM = """Translate a formal argument evaluation into a clear, traceable explanation.

Rules:
1. Do NOT add your own reasoning -- only translate what the formal evaluation shows
2. Cite every argument by its ID in brackets, e.g. [A3]
3. Do NOT use hedging language ("seems", "might", "could be")
4. If the conclusion is not justified, say so clearly and explain which attack succeeded

Output structure (use exactly these headers):
CONCLUSION: [text]
ESTADO: Justificada | No justificada | Ambigua

POR QUE SE SOSTIENE:
  [explanation of winning arguments]

POR QUE LOS CONTRA-ARGUMENTOS NO PROSPERARON:
  [explanation of each defeated argument]

TENSION NO RESUELTA: [list or "ninguna"]"""


NARRATOR_TEMPLATE = """Argument graph:
{graph_cnl}

Evaluation result:
- Conclusion: {conclusion}
- Justified: {justified}
- Supporting argument: {supporting_id}
- Grounded extension (accepted): {accepted}
- Defeated: {defeated}
- Undecidable: {undecidable}

Translate this formal evaluation into a traceable explanation."""


print("Modulo 4 OK: todos los prompts definidos")
# Out:
# Modulo 4 OK: todos los prompts definidos

# %% [markdown]
# ## Modulo 5 -- Clientes LLM
#
# Todos los clientes implementan la misma interfaz: `call(system, user) -> str`
#
# | Cliente | Proveedor | Requiere |
# |---------|-----------|----------|
# | `AnthropicClient` | Anthropic -- Claude | `ANTHROPIC_API_KEY` |
# | `OpenAIClient` | OpenAI -- GPT | `OPENAI_API_KEY` |
# | `GeminiClient` | Google -- Gemini | `GEMINI_API_KEY` |
# | `OllamaClient` | Ollama -- modelos locales | Ollama server en localhost |
# | `HuggingFaceClient` | HuggingFace -- Inference API | `HF_TOKEN` |
# | `HuggingFaceLocalClient` | HuggingFace -- GPU local | GPU T4/A100 en Colab |

# %%
from __future__ import annotations
import os
from abc import ABC, abstractmethod


class LLMClient(ABC):
    @abstractmethod
    def call(self, system: str, user: str) -> str: ...


class AnthropicClient(LLMClient):
    # Modelos: "claude-sonnet-4-6" (default), "claude-haiku-4-5-20251001" (rapido)
    def __init__(self, api_key: str | None = None, model: str = "claude-sonnet-4-6",
                 temperature: float = 0.0):
        import anthropic
        key = api_key or os.environ.get("ANTHROPIC_API_KEY")
        if not key:
            raise ValueError("Falta ANTHROPIC_API_KEY.")
        self._client = anthropic.Anthropic(api_key=key)
        self._model = model
        self._temperature = temperature

    def call(self, system: str, user: str) -> str:
        msg = self._client.messages.create(
            model=self._model, max_tokens=2048, system=system,
            temperature=self._temperature,
            messages=[{"role": "user", "content": user}],
        )
        return msg.content[0].text


class OpenAIClient(LLMClient):
    # Modelos: "gpt-4o" (default), "gpt-4o-mini" (economico)
    def __init__(self, api_key: str | None = None, model: str = "gpt-4o",
                 temperature: float = 0.0):
        from openai import OpenAI
        key = api_key or os.environ.get("OPENAI_API_KEY")
        if not key:
            raise ValueError("Falta OPENAI_API_KEY.")
        self._client = OpenAI(api_key=key)
        self._model = model
        self._temperature = temperature

    def call(self, system: str, user: str) -> str:
        response = self._client.chat.completions.create(
            model=self._model,
            messages=[{"role": "system", "content": system}, {"role": "user", "content": user}],
            max_tokens=2048,
            temperature=self._temperature,
        )
        return response.choices[0].message.content


class GeminiClient(LLMClient):
    # Modelos: "gemini-2.5-flash" (default), "gemini-2.5-pro" (mas potente)
    def __init__(self, api_key: str | None = None, model: str = "gemini-2.5-flash",
                 temperature: float = 0.0):
        from google import genai
        key = api_key or os.environ.get("GEMINI_API_KEY")
        if not key:
            raise ValueError("Falta GEMINI_API_KEY. Gratis en https://aistudio.google.com")
        self._client = genai.Client(api_key=key)
        self._model = model
        self._temperature = temperature

    def call(self, system: str, user: str) -> str:
        from google.genai import types
        response = self._client.models.generate_content(
            model=self._model,
            config=types.GenerateContentConfig(
                system_instruction=system, temperature=self._temperature
            ),
            contents=user,
        )
        return response.text


class OllamaClient(LLMClient):
    # Instalacion en Colab:
    #   !curl -fsSL https://ollama.com/install.sh | sh
    #   import subprocess; subprocess.Popen(["ollama", "serve"])
    #   !ollama pull llama3.2
    def __init__(self, model: str = "llama3.2", base_url: str = "http://localhost:11434/v1",
                 temperature: float = 0.0):
        from openai import OpenAI
        self._client = OpenAI(api_key="ollama", base_url=base_url)
        self._model = model
        self._temperature = temperature

    def call(self, system: str, user: str) -> str:
        response = self._client.chat.completions.create(
            model=self._model,
            messages=[{"role": "system", "content": system}, {"role": "user", "content": user}],
            max_tokens=2048,
            temperature=self._temperature,
        )
        return response.choices[0].message.content


class HuggingFaceClient(LLMClient):
    # Inference API en la nube. Token gratis en https://huggingface.co/settings/tokens
    #
    # Modelos compatibles con el router de HF (usar exactamente estos nombres):
    #   "Qwen/Qwen2.5-7B-Instruct"             7B, buena calidad (default)
    #   "Qwen/Qwen2.5-72B-Instruct"            72B, muy potente
    #   "meta-llama/Llama-3.2-3B-Instruct"     3B, rapido y liviano
    #   "mistralai/Mistral-Nemo-Instruct-2407"  12B, buena calidad
    #   "microsoft/Phi-3.5-mini-instruct"        3.8B, rapido
    def __init__(self, api_key: str | None = None,
                 model: str = "Qwen/Qwen2.5-7B-Instruct",
                 temperature: float = 0.0):
        from huggingface_hub import InferenceClient
        key = api_key or os.environ.get("HF_TOKEN")
        if not key:
            raise ValueError("Falta HF_TOKEN. Gratis en https://huggingface.co/settings/tokens")
        self._client = InferenceClient(api_key=key)
        self._model = model
        self._temperature = temperature

    def call(self, system: str, user: str) -> str:
        response = self._client.chat_completion(
            model=self._model,
            messages=[{"role": "system", "content": system}, {"role": "user", "content": user}],
            max_tokens=2048,
            temperature=self._temperature,
        )
        return response.choices[0].message.content


class HuggingFaceLocalClient(LLMClient):
    # Corre un modelo HuggingFace directamente en la GPU del entorno.
    #
    # REQUISITOS:
    #   - GPU habilitada en Colab: Entorno de ejecucion -> Cambiar tipo -> GPU T4
    #   - Las dependencias ya se instalaron en la celda de instalacion (arriba)
    #
    # Primera ejecucion: descarga el modelo (varios GB, 5-15 minutos).
    # Ejecuciones siguientes: carga desde cache en ~30 segundos.
    #
    # Modelos que caben en T4 (15GB VRAM) con cuantizacion 4-bit:
    #   "Qwen/Qwen2.5-7B-Instruct"                  excelente calidad (default)
    #   "meta-llama/Meta-Llama-3.1-8B-Instruct"     muy bueno (requiere aceptar licencia en HF)
    #   "mistralai/Mistral-7B-Instruct-v0.3"         bueno para instrucciones
    #   "microsoft/Phi-3.5-mini-instruct"            3.8B, muy rapido
    #
    # Para Colab Pro con A100 (40GB VRAM):
    #   "Qwen/Qwen2.5-14B-Instruct"
    #   "meta-llama/Llama-3.1-70B-Instruct"         (70B en 4-bit)
    #
    # temperature=0.0 (default) -> generacion greedy/determinista (do_sample=False).
    def __init__(
        self,
        model_id: str = "Qwen/Qwen2.5-7B-Instruct",
        load_in_4bit: bool = True,
        max_new_tokens: int = 2048,
        temperature: float = 0.0,
    ):
        from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
        import torch

        self._max_new_tokens = max_new_tokens
        self._model_id = model_id
        self._temperature = temperature

        print(f"Cargando {model_id}...")
        print("(La primera vez descarga el modelo; puede tardar varios minutos)")

        self._tokenizer = AutoTokenizer.from_pretrained(model_id)

        quantization_config = None
        if load_in_4bit:
            quantization_config = BitsAndBytesConfig(
                load_in_4bit=True,
                bnb_4bit_compute_dtype=torch.float16,
                bnb_4bit_quant_type="nf4",
                bnb_4bit_use_double_quant=True,
            )

        self._model = AutoModelForCausalLM.from_pretrained(
            model_id,
            quantization_config=quantization_config,
            device_map="auto",
            torch_dtype=torch.float16 if not load_in_4bit else None,
        )
        self._model.eval()
        print(f"Modelo listo en: {next(self._model.parameters()).device}")

    def call(self, system: str, user: str) -> str:
        import torch
        messages = [
            {"role": "system", "content": system},
            {"role": "user", "content": user},
        ]
        device = next(self._model.parameters()).device

        chat_text = self._tokenizer.apply_chat_template(
            messages, add_generation_prompt=True, tokenize=False,
        )
        enc = self._tokenizer(
            chat_text,
            return_tensors="pt",
            add_special_tokens=False,
        ).to(device)

        input_ids = enc["input_ids"]
        attention_mask = enc["attention_mask"]
        prompt_len = input_ids.shape[-1]

        gen_kwargs = dict(
            input_ids=input_ids,
            attention_mask=attention_mask,
            max_new_tokens=self._max_new_tokens,
            repetition_penalty=1.1,
            pad_token_id=self._tokenizer.eos_token_id,
        )
        if self._temperature and self._temperature > 0:
            gen_kwargs.update(do_sample=True, temperature=self._temperature, top_p=0.9)
        else:
            gen_kwargs.update(do_sample=False)

        with torch.no_grad():
            outputs = self._model.generate(**gen_kwargs)
        new_tokens = outputs[0][prompt_len:]
        return self._tokenizer.decode(new_tokens, skip_special_tokens=True)


def call_with_retry(
    client: LLMClient,
    system: str,
    user: str,
    tag: str,
    known_ids: set,
    max_retries: int = 2,
) -> str:
    # Reintentos automaticos si el CNL generado tiene errores de formato.
    current_user = user
    last_block = ""
    for attempt in range(max_retries + 1):
        raw = client.call(system, current_user)
        block = extract_tagged_block(raw, tag)
        errors = validate_block(block, known_ids)
        last_block = block
        if not errors:
            return block
        if attempt < max_retries:
            current_user = (
                user + f"\n\nPrevious response had formatting errors: {errors}. "
                "Please fix them and respond again with the corrected CNL."
            )
    return last_block


print("Modulo 5 OK: LLMClient, AnthropicClient, OpenAIClient, GeminiClient, OllamaClient,")
print("             HuggingFaceClient, HuggingFaceLocalClient, call_with_retry")
print("             (generacion determinista por defecto: temperature=0.0)")
# Out:
# Modulo 5 OK: LLMClient, AnthropicClient, OpenAIClient, GeminiClient, OllamaClient,
#              HuggingFaceClient, HuggingFaceLocalClient, call_with_retry
#              (generacion determinista por defecto: temperature=0.0)

# %% [markdown]
# ## Modulo 6 -- Generador de Argumentos (C1)
#
# - Primera llamada (`graph=None`): genera argumentos iniciales y define la conclusion target.
# - Llamadas siguientes: genera argumentos para rebatir ataques B, continuando la numeracion A-ID.

# %%
from __future__ import annotations


def generate_arguments(
    problem: str,
    client: LLMClient,
    graph: ArgumentGraph | None = None,
) -> tuple[list, list, str | None]:
    is_initial = graph is None
    known_ids  = set() if is_initial else set(graph.arguments.keys())

    if is_initial:
        user = GENERATOR_INITIAL_TEMPLATE.format(problem=problem)
    else:
        user = GENERATOR_RESPONSE_TEMPLATE.format(
            problem=problem, current_graph=graph.to_cnl()
        )

    block = call_with_retry(client, GENERATOR_SYSTEM, user, "ARGUMENTOS", known_ids)
    args, attacks, conclusion = parse_cnl_block(block)
    for a in args:
        a.stance = "pro"   # C1 siempre defiende la tesis
    return args, attacks, (conclusion if is_initial else None)


print("Modulo 6 OK: generate_arguments")
# Out:
# Modulo 6 OK: generate_arguments

# %% [markdown]
# ## Modulo 7 -- Abogado del Diablo (C2)
#
# Genera los mejores contra-argumentos posibles (steel-manning).
# Si no puede encontrar ataques significativos, responde `SIN_NUEVOS_ATAQUES`.

# %%
from __future__ import annotations


def generate_attacks(
    problem: str,
    graph: ArgumentGraph,
    client: LLMClient,
) -> tuple[list, list, bool]:
    # Devuelve (nuevos_argumentos_B, nuevos_ataques, exhausted).
    # exhausted=True significa que el loop debe terminar.
    user = DEVIL_TEMPLATE.format(problem=problem, current_graph=graph.to_cnl())
    block = call_with_retry(client, DEVIL_SYSTEM, user, "ATAQUES", set())

    if not block.strip() or "SIN_NUEVOS_ATAQUES" in block:
        return [], [], True

    args, attacks, _ = parse_cnl_block(block)
    for a in args:
        a.stance = "con"   # C2 siempre ataca la tesis

    # Descartar ataques cuyo atacante no existe (ni en el grafo ni entre los nuevos B-IDs)
    valid_ids = set(graph.arguments.keys()) | {a.id for a in args}
    attacks   = [atk for atk in attacks if atk.attacker_id in valid_ids]

    return args, attacks, False


print("Modulo 7 OK: generate_attacks")
# Out:
# Modulo 7 OK: generate_attacks

# %% [markdown]
# ## Modulo 8 -- Loop Adversarial
#
# Orquesta el dialogo C1 <-> C2 para construir el grafo.
#
# Termina cuando:
# 1. C2 emite `SIN_NUEVOS_ATAQUES`
# 2. Se alcanza `max_rounds`
# 3. El grafo no crece en la ultima ronda (sin progreso)

# %%
from __future__ import annotations


def _graph_size(graph: ArgumentGraph) -> int:
    return len(graph.arguments) + len(graph.attacks)


def _merge_into(graph: ArgumentGraph, args: list, attacks: list) -> None:
    for a in args:
        graph.arguments[a.id] = a
    existing = {(atk.attacker_id, atk.target_id, atk.attack_type)
                for atk in graph.attacks}
    for atk in attacks:
        key = (atk.attacker_id, atk.target_id, atk.attack_type)
        if key not in existing:
            graph.attacks.append(atk)
            existing.add(key)


def run_adversarial_loop(
    problem: str,
    client: LLMClient,
    max_rounds: int = 3,
    verbose: bool = False,
) -> ArgumentGraph:
    def _log(msg: str) -> None:
        if verbose:
            print(f"  [loop] {msg}")

    args, attacks, target_conclusion = generate_arguments(problem, client, graph=None)
    graph = ArgumentGraph(
        arguments={a.id: a for a in args},
        attacks=list(attacks),
        target_conclusion=target_conclusion or "",
    )
    _log(f"ronda 0 -- generador: {len(args)} args, {len(attacks)} ataques")

    prev_size = _graph_size(graph)
    for round_num in range(max_rounds):
        new_args, new_attacks, exhausted = generate_attacks(problem, graph, client)
        _log(f"ronda {round_num+1} -- diablo: {len(new_args)} args, {len(new_attacks)} ataques, agotado={exhausted}")
        _merge_into(graph, new_args, new_attacks)

        if exhausted or _graph_size(graph) == prev_size:
            break
        prev_size = _graph_size(graph)

        new_args, new_attacks, _ = generate_arguments(problem, client, graph=graph)
        _log(f"ronda {round_num+1} -- generador (respuesta): {len(new_args)} args, {len(new_attacks)} ataques")
        _merge_into(graph, new_args, new_attacks)

        if _graph_size(graph) == prev_size:
            break
        prev_size = _graph_size(graph)

    return graph


print("Modulo 8 OK: run_adversarial_loop")
# Out:
# Modulo 8 OK: run_adversarial_loop

# %% [markdown]
# ## Modulo 9 -- Narrador (C5)
#
# Traduce el resultado formal a lenguaje natural trazable.
# No agrega razonamiento propio: solo traduce lo que el grafo y la evaluacion muestran.

# %%
from __future__ import annotations


def narrate(graph: ArgumentGraph, result: EvaluationResult, client: LLMClient) -> str:
    user = NARRATOR_TEMPLATE.format(
        graph_cnl=graph.to_cnl(),
        conclusion=result.conclusion,
        justified=result.justified,
        supporting_id=result.supporting_argument_id or "ninguno",
        accepted=result.grounded_extension,
        defeated=result.defeated,
        undecidable=result.undecidable,
    )
    return client.call(NARRATOR_SYSTEM, user)


print("Modulo 9 OK: narrate")
# Out:
# Modulo 9 OK: narrate

# %% [markdown]
# ## Modulo 10 -- Pipeline
#
# Orquesta todos los componentes en 3 pasos:
#
# 1. `run_adversarial_loop` -> construye el grafo argumentativo (C1 <-> C2)
# 2. `grounded_extension` -> evalua que argumentos sobreviven (motor Dung)
# 3. `narrate` -> genera la explicacion en lenguaje natural (C5)

# %%
from __future__ import annotations
import json as _json


class Pipeline:
    # Orquesta el flujo completo de argumentacion formal.
    #
    # Uso basico:
    #   client   = GeminiClient(api_key="tu-key")
    #   pipeline = Pipeline(client=client, max_rounds=2)
    #   result   = pipeline.run("Es etico el trabajo remoto obligatorio?")
    #   print(result.explanation)

    def __init__(self, client: LLMClient, max_rounds: int = 3, verbose: bool = False):
        self._client     = client
        self._max_rounds = max_rounds
        self._verbose    = verbose

    def run(self, problem: str) -> PipelineResult:
        if self._verbose:
            print(f"\nAnalizando: {problem[:80]}...")
            print()

        graph = run_adversarial_loop(
            problem, self._client, self._max_rounds, verbose=self._verbose
        )

        if self._verbose:
            print(f"\nGrafo final: {len(graph.arguments)} argumentos, {len(graph.attacks)} ataques")
            print("Evaluando extension fundamentada (Dung)...")

        evaluation = grounded_extension(graph)

        if self._verbose:
            estado = "JUSTIFICADA" if evaluation.justified else "NO JUSTIFICADA"
            print(f"{estado}  |  Soporte: {evaluation.supporting_argument_id}  |  Derrotados: {evaluation.defeated}")
            print("Generando explicacion...")

        explanation = narrate(graph, evaluation, self._client)
        return PipelineResult(explanation=explanation, graph=graph, evaluation=evaluation)

    def save(self, result: PipelineResult, path: str) -> None:
        data = {
            "conclusion":             result.evaluation.conclusion,
            "justified":              result.evaluation.justified,
            "supporting_argument_id": result.evaluation.supporting_argument_id,
            "grounded_extension":     result.evaluation.grounded_extension,
            "defeated":               result.evaluation.defeated,
            "undecidable":            result.evaluation.undecidable,
            "explanation":            result.explanation,
            "graph_cnl":              result.graph.to_cnl(),
        }
        with open(path, "w", encoding="utf-8") as f:
            _json.dump(data, f, ensure_ascii=False, indent=2)
        print(f"Resultado guardado en: {path}")


print("Modulo 10 OK: Pipeline")
print()
print("Sistema completo. Todos los modulos cargados:")
for mod in ["Argument/Attack/ArgumentGraph/EvaluationResult/PipelineResult",
            "parse_cnl_block / validate_block / extract_tagged_block",
            "grounded_extension",
            "Prompts (GENERATOR, DEVIL, NARRATOR)",
            "LLMClient / AnthropicClient / OpenAIClient / GeminiClient",
            "OllamaClient / HuggingFaceClient / HuggingFaceLocalClient",
            "generate_arguments", "generate_attacks",
            "run_adversarial_loop", "narrate", "Pipeline"]:
    print(f"  {mod}")
# Out:
# Modulo 10 OK: Pipeline
#
# Sistema completo. Todos los modulos cargados:
#   Argument/Attack/ArgumentGraph/EvaluationResult/PipelineResult
#   parse_cnl_block / validate_block / extract_tagged_block
#   grounded_extension
#   Prompts (GENERATOR, DEVIL, NARRATOR)
#   LLMClient / AnthropicClient / OpenAIClient / GeminiClient
#   OllamaClient / HuggingFaceClient / HuggingFaceLocalClient
#   generate_arguments
#   generate_attacks
#   run_adversarial_loop
#   narrate
#   Pipeline

# %%
# Modulo 11 -- Reporte (fuente unica de verdad: pantalla == archivo .txt)


def build_report(question: str, result: PipelineResult, width: int = 65) -> str:
    sep = "=" * width
    ev = result.evaluation
    return "\n".join([
        sep,
        f"PREGUNTA: {question}",
        sep,
        "",
        "ANALISIS FORMAL",
        sep,
        "",
        result.explanation,
        "",
        "-" * width,
        f"Argumentos aceptados : {ev.grounded_extension}",
        f"Argumentos derrotados: {ev.defeated}",
        f"Indecidibles         : {ev.undecidable or 'ninguno'}",
        f"Soporte              : {ev.supporting_argument_id or 'ninguno'}",
        f"Justificada          : {ev.justified}",
        "",
        sep,
        "GRAFO DE ARGUMENTACION (CNL)",
        sep,
        "",
        result.graph.to_cnl(),
    ])


print("Modulo 11 OK: build_report")
# Out:
# Modulo 11 OK: build_report

# %%
# Modulo 12 -- Visualizacion del grafo  # NO-TEST (requiere matplotlib/networkx de Colab)


def draw_graph(graph: ArgumentGraph, result: EvaluationResult, path: str | None = None):
    # Dibuja el grafo coloreado por estado: verde=IN, rojo=OUT, amarillo=UNDEC.
    # Aristas: solidas = derrotas efectivas; punteadas grises = ataques anulados
    # por la semantica (p. ej. un REFUTA contra un argumento estricto).
    import matplotlib.pyplot as plt
    import networkx as nx

    states = classify_nodes(graph, result)
    color_map = {"in": "#7CB342", "out": "#E53935", "undec": "#FDD835"}

    G = nx.DiGraph()
    for arg_id in graph.arguments:
        G.add_node(arg_id)

    defeaters = compute_defeats(graph)
    effective = {(atk, tgt) for tgt, atts in defeaters.items() for atk in atts}
    declared = {(a.attacker_id, a.target_id) for a in graph.attacks
                if a.attacker_id in graph.arguments and a.target_id in graph.arguments}
    for (u, v) in effective | declared:
        G.add_edge(u, v)

    pos = nx.spring_layout(G, seed=42, k=1.2)
    node_colors = [color_map[states[n]] for n in G.nodes]

    fig, ax = plt.subplots(figsize=(10, 7))
    nx.draw_networkx_nodes(G, pos, node_color=node_colors, node_size=1400, ax=ax)
    nx.draw_networkx_labels(G, pos, font_size=9, ax=ax)

    eff_edges = [e for e in G.edges if e in effective]
    null_edges = [e for e in G.edges if e not in effective]
    nx.draw_networkx_edges(G, pos, edgelist=eff_edges, edge_color="#333333",
                           width=1.8, arrows=True, arrowsize=18, ax=ax)
    nx.draw_networkx_edges(G, pos, edgelist=null_edges, edge_color="#BBBBBB",
                           style="dashed", width=1.0, arrows=True, arrowsize=12, ax=ax)

    legend = [
        plt.Line2D([0], [0], marker="o", color="w", markerfacecolor=color_map["in"],
                   markersize=12, label="Aceptado (IN)"),
        plt.Line2D([0], [0], marker="o", color="w", markerfacecolor=color_map["out"],
                   markersize=12, label="Derrotado (OUT)"),
        plt.Line2D([0], [0], marker="o", color="w", markerfacecolor=color_map["undec"],
                   markersize=12, label="Indecidible (UNDEC)"),
    ]
    ax.legend(handles=legend, loc="best")
    ax.set_title("Grafo de argumentacion  (solido = derrota efectiva, punteado = ataque anulado)")
    ax.axis("off")
    fig.tight_layout()

    if path:
        fig.savefig(path, dpi=150, bbox_inches="tight")
    plt.show()
    plt.close(fig)


print("Modulo 12 OK: draw_graph")
# Out:
# Modulo 12 OK: draw_graph

# %%
# Modulo 13 -- Tests de componentes (stance, dedup, reporte)

class _StubClient(LLMClient):
    def __init__(self, response: str):
        self._response = response
    def call(self, system: str, user: str) -> str:
        return self._response

# stance: generate_arguments -> pro
_pro_cnl = '<ARGUMENTOS>\nARG A1: "p" => "q"\nCONCLUSION: "q"\n</ARGUMENTOS>'
_args, _atks, _concl = generate_arguments("tema", _StubClient(_pro_cnl), graph=None)
assert _args and all(a.stance == "pro" for a in _args), "generate_arguments -> stance pro"
assert _concl == "q"

# stance: generate_attacks -> con
_g = ArgumentGraph(
    arguments={"A1": Argument("A1", ["p"], "q", "defeasible", stance="pro")},
    attacks=[], target_conclusion="q",
)
_dev_cnl = '<ATAQUES>\nARG B1: "r" => "no q"\nB1 REFUTA A1\n</ATAQUES>'
_bargs, _batks, _exhausted = generate_attacks("tema", _g, _StubClient(_dev_cnl))
assert _bargs and all(a.stance == "con" for a in _bargs), "generate_attacks -> stance con"
assert _exhausted is False and any(x.target_id == "A1" for x in _batks)

# dedup en _merge_into
_gm = ArgumentGraph()
_dup = [Attack("B1", "A1", "rebuttal"), Attack("B1", "A1", "rebuttal")]
_merge_into(_gm, [Argument("A1", ["p"], "q", "defeasible"),
                  Argument("B1", ["r"], "s", "defeasible")], _dup)
assert len(_gm.attacks) == 1, "_merge_into debe deduplicar ataques exactos"
_merge_into(_gm, [], [Attack("B1", "A1", "rebuttal")])
assert len(_gm.attacks) == 1, "no re-agregar un duplicado entre llamadas"
_merge_into(_gm, [], [Attack("B1", "A1", "undercut")])
assert len(_gm.attacks) == 2, "distinto attack_type no es duplicado"

# build_report: paridad de contenido (lo que va a pantalla == lo que va al .txt)
_evb = EvaluationResult(conclusion="q", justified=True, supporting_argument_id="A1",
                        grounded_extension=["A1"], defeated=["B1"], undecidable=[])
_grb = ArgumentGraph(
    arguments={"A1": Argument("A1", ["p"], "q", "defeasible", stance="pro")},
    attacks=[], target_conclusion="q",
)
_prb = PipelineResult(explanation="EXPLICACION_X", graph=_grb, evaluation=_evb)
_rep = build_report("PREGUNTA_X", _prb)
for _needle in ["PREGUNTA_X", "EXPLICACION_X", "A1",
                "GRAFO DE ARGUMENTACION", "Soporte", "Justificada"]:
    assert _needle in _rep, f"build_report debe incluir {_needle}"

print("Modulo 13 OK: stance por componente")
# Out:
# Modulo 13 OK: stance por componente

# %% [markdown]
# ## Configuracion -- Elige tu proveedor LLM
#
# Ejecuta **solo una** de las siguientes celdas.
#
# > Si algun nombre da `NameError`, ejecuta primero **Runtime > Ejecutar todo** (Ctrl+F9).

# %% [markdown]
# ### Opcion A -- Anthropic Claude
#
# Key en https://console.anthropic.com

# %%
ANTHROPIC_API_KEY = "sk-ant-..."   # reemplaza con tu key

client = AnthropicClient(
    api_key=ANTHROPIC_API_KEY,
    model="claude-sonnet-4-6",
)
print("Usando Anthropic Claude:", client._model)
# Out:
# Usando Anthropic Claude: claude-sonnet-4-6

# %% [markdown]
# ### Opcion B -- OpenAI GPT
#
# Key en https://platform.openai.com/api-keys

# %%
OPENAI_API_KEY = "sk-proj-..."   # reemplaza con tu key

client = OpenAIClient(
    api_key=OPENAI_API_KEY,
    model="gpt-4o",
)
print("Usando OpenAI:", client._model)
# Out:
# Usando OpenAI: gpt-4o

# %% [markdown]
# ### Opcion C -- Google Gemini
#
# Key gratuita en https://aistudio.google.com (~20 req/dia)

# %%
GEMINI_API_KEY = "AIza..."   # reemplaza con tu key

client = GeminiClient(
    api_key=GEMINI_API_KEY,
    model="gemini-2.5-flash",
)
print("Usando Google Gemini:", client._model)
# Out:
# Usando Google Gemini: gemini-2.5-flash

# %% [markdown]
# ### Opcion D -- Ollama (local, 100% gratis)
#
# ```bash
# !curl -fsSL https://ollama.com/install.sh | sh
# import subprocess; subprocess.Popen(["ollama", "serve"])
# !ollama pull llama3.2
# ```

# %%
client = OllamaClient(
    model="llama3.2",
    base_url="http://localhost:11434/v1",
)
print("Usando Ollama:", client._model)
# Out:
# Usando Ollama: llama3.2

# %% [markdown]
# ### Opcion E -- HuggingFace Inference API (nube, tier gratuito)
#
# Token gratuito en https://huggingface.co/settings/tokens
#
# Modelos compatibles con el router de HF:
# - `Qwen/Qwen2.5-7B-Instruct` (default, buena calidad)
# - `Qwen/Qwen2.5-72B-Instruct` (muy potente)
# - `meta-llama/Llama-3.2-3B-Instruct` (rapido)
# - `mistralai/Mistral-Nemo-Instruct-2407` (12B)

# %%
HF_TOKEN = "hf_..."   # reemplaza con tu token

client = HuggingFaceClient(
    api_key=HF_TOKEN,
    model="Qwen/Qwen2.5-7B-Instruct",
)
print("Usando HuggingFace API:", client._model)
# Out:
# Usando HuggingFace API: Qwen/Qwen2.5-7B-Instruct

# %% [markdown]
# ### Opcion F -- HuggingFace Local (GPU de Colab, sin rate limits)
#
# **Requisito:** activar GPU antes de ejecutar.
# Colab: Entorno de ejecucion -> Cambiar tipo de entorno -> GPU T4 (gratis)
#
# Primera ejecucion: descarga el modelo (~14GB para 7B en 4-bit, tarda 5-15 min).
# Ejecuciones siguientes: carga desde cache en ~30 segundos.

# %%
client = HuggingFaceLocalClient(
    model_id="Qwen/Qwen2.5-7B-Instruct",   # 7B, excelente calidad, cabe en T4
    # model_id="microsoft/Phi-3.5-mini-instruct",  # 3.8B, mas rapido
    # model_id="meta-llama/Meta-Llama-3.1-8B-Instruct",  # 8B (requiere licencia HF)
    load_in_4bit=True,
)
print("Usando HuggingFace Local:", client._model_id)
# Out:
# Cargando Qwen/Qwen2.5-7B-Instruct...
# (La primera vez descarga el modelo; puede tardar varios minutos)
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:124: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json:   0%|          | 0.00/27.8k [00:00<?, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:213: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# Modelo listo en: cuda:0
# Usando HuggingFace Local: Qwen/Qwen2.5-7B-Instruct

# %% [markdown]
# ## A opinar que es gratis!
#
# Modifica `PREGUNTA` con el tema que quieras analizar.
# - `max_rounds=2` -> aprox 7 llamadas LLM (recomendado para empezar)
# - `verbose=True` -> muestra el progreso ronda a ronda

# %%
import datetime as _dt  # NO-TEST (la demo ejecuta el pipeline: requiere un proveedor LLM)

PREGUNTA = "Should social media platforms be regulated by governments?"  # <-- escribe tu pregunta aqui

# Otras preguntas de ejemplo:
# PREGUNTA = "Deberia el voto ser obligatorio en una democracia?"
# PREGUNTA = "Es el capitalismo el mejor sistema economico posible?"
# PREGUNTA = "Should social media platforms be regulated by governments?"

pipeline = Pipeline(
    client=client,
    max_rounds=2,
    verbose=True,
)

print("=" * 65)
print("PREGUNTA:", PREGUNTA)
print("=" * 65)

result = pipeline.run(PREGUNTA)

# Fuente unica de verdad: el mismo texto va a pantalla y al .txt
_report = build_report(PREGUNTA, result)
print()
print(_report)

# Guardado con timestamp (JSON estructurado + informe TXT + grafo PNG)
_ts = _dt.datetime.now().strftime("%Y%m%d_%H%M%S")
_json_path = f"resultado_{_ts}.json"
_txt_path  = f"informe_{_ts}.txt"
_png_path  = f"grafo_{_ts}.png"

pipeline.save(result, _json_path)
with open(_txt_path, "w", encoding="utf-8") as _f:
    _f.write(_report)

# Grafo: inline en Colab + PNG (misma figura)
draw_graph(result.graph, result.evaluation, path=_png_path)

print()
print("Archivos guardados:")
print(f"  {_json_path}  ->  datos estructurados (JSON)")
print(f"  {_txt_path}  ->  informe completo (TXT, identico a lo de arriba)")
print(f"  {_png_path}  ->  grafo coloreado IN/OUT/UNDEC (PNG)")
# Out:
# =================================================================
# PREGUNTA: Should social media platforms be regulated by governments?
# =================================================================
#
# Analizando: Should social media platforms be regulated by governments?...
#
#   [loop] ronda 0 -- generador: 5 args, 0 ataques
#   [loop] ronda 1 -- diablo: 5 args, 25 ataques, agotado=False
#   [loop] ronda 1 -- generador (respuesta): 33 args, 32 ataques
#   [loop] ronda 2 -- diablo: 0 args, 32 ataques, agotado=False
#   [loop] ronda 2 -- generador (respuesta): 38 args, 38 ataques
#
# Grafo final: 80 argumentos, 127 ataques
# Evaluando extension fundamentada (Dung)...
# NO JUSTIFICADA  |  Soporte: None  |  Derrotados: []
# Generando explicacion...
#
# =================================================================
# PREGUNTA: Should social media platforms be regulated by governments?
# =================================================================
#
# ANALISIS FORMAL
# =================================================================
#
# CONCLUSION: "Social media platforms should be regulated by governments"
# ESTADO: No justificada
#
# POR QUE SE SOSTIENE:
#   Ninguno de los argumentos en favor de la regulación de las plataformas sociales por parte del gobierno ha sido justificado.
#
# POR QUE LOS CONTRA-ARGUMENTOS NO PROSPERARON:
#   - Argumento B1: "Social media platforms are essential for free speech and democracy" => "Social media platforms should not be regulated by governments"
#     Este argumento no prospera porque varios argumentos adicionales (A6, A7, A8, A9, A10, A11, A12, A13, A14, A15, A16, A17, A18, A19, A20, A21, A22, A23, A24, A25, A26, A27, A28, A29, A30, A31, A32, A33, A34, A35, A36, A37, A38, A39, A40, A41, A42, A43, A44, A45, A46, A47, A48, A49, A50, A51, A52, A53, A54, A55, A56, A57, A58, A59, A60, A61, A62, A63, A64, A65, A66, A67, A68, A69, A70, A71, A72, A73, A74, A75) proporcionan razones convincentes para regular las plataformas sociales.
#
#   - Argumento B2: "Many social media users do not rely on them for critical news sources" => "Social media platforms should not be regulated by governments"
#     Este argumento no prospera porque otros argumentos (A6, A7, A8, A9, A10, A11, A12, A13, A14, A15, A16, A17, A18, A19, A20, A21, A22, A23, A24, A25, A26, A27, A28, A29, A30, A31, A32, A33, A34, A35, A36, A37, A38, A39, A40, A41, A42, A43, A44, A45, A46, A47, A48, A49, A50, A51, A52, A53, A54, A55, A56, A57, A58, A59, A60, A61, A62, A63, A64, A65, A66, A67, A68, A69, A70, A71, A72, A73, A74, A75) demuestran que incluso si algunos usuarios no dependen de ellas para noticias críticas, el impacto general negativo de estas plataformas requiere regulación.
#
#   - Argumento B3: "Regulation could stifle innovation and limit freedom of expression" => "Social media platforms should not be regulated by governments"
#     Este argumento no prospera porque otros argumentos (A6, A7, A8, A9, A10, A11, A12, A13, A14, A15, A16, A17, A18, A19, A20, A21, A22, A23, A24, A25, A26, A27, A28, A29, A30, A31, A32, A33, A34, A35, A36, A37, A38, A39, A40, A41, A42, A43, A44, A45, A46, A47, A48, A49, A50, A51, A52, A53, A54, A55, A56, A57, A58, A59, A60, A61, A62, A63, A64, A65, A66, A67, A68, A69, A70, A71, A72, A73, A74, A75) indican que la regulación puede proteger la libertad de expresión y fomentar una sociedad más informada y segura.
#
#   - Argumento B4: "Alternative forms of media already exist and can fulfill similar roles" => "Social media platforms should not be regulated by governments"
#     Este argumento no prospera porque otros argumentos (A6, A7, A8, A9, A10, A11, A12, A13, A14, A15, A16, A17, A18, A19, A20, A21, A22, A23, A24, A25, A26, A27, A28, A29, A30, A31, A32, A33, A34, A35, A36, A37, A38, A39, A40, A41, A42, A43, A44, A45, A46, A47, A48, A49, A50, A51, A52, A53, A54, A55, A56, A57, A58, A59, A60, A61, A62, A63, A64, A65, A66, A67, A68, A69, A70, A71, A72, A73, A74, A75) muestran que la regulación es necesaria para mitigar los daños causados por las plataformas sociales.
#
#   - Argumento B5: "User behavior can change without external regulation through internal policies" => "Social media platforms should not be regulated by governments"
#     Este argumento no prospera porque otros argumentos (A6, A7, A8, A9, A10, A11, A12, A13, A14, A15, A16, A17, A18, A19, A20, A21, A22, A23, A24, A25, A26, A27, A28, A29, A30, A31, A32, A33, A34, A35, A36, A37, A38, A39, A40, A41, A42, A43, A44, A45, A46, A47, A48, A49, A50, A51, A52, A53, A54, A55, A56, A57, A58, A59, A60, A61, A62, A63, A64, A65, A66, A67, A68, A69, A70, A71, A72, A73, A74, A75) demuestran que la falta de regulación externa puede permitir comportamientos perjudiciales que no se pueden corregir internamente.
#
# TENSION NO RESUELTA: ninguna
#
# -----------------------------------------------------------------
# Argumentos aceptados : []
# Argumentos derrotados: []
# Indecidibles         : ['A1', 'A10', 'A11', 'A12', 'A13', 'A14', 'A15', 'A16', 'A17', 'A18', 'A19', 'A2', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'A3', 'A30', 'A31', 'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'A4', 'A40', 'A41', 'A42', 'A43', 'A44', 'A45', 'A46', 'A47', 'A48', 'A49', 'A5', 'A50', 'A51', 'A52', 'A53', 'A54', 'A55', 'A56', 'A57', 'A58', 'A59', 'A6', 'A60', 'A61', 'A62', 'A63', 'A64', 'A65', 'A66', 'A67', 'A68', 'A69', 'A7', 'A70', 'A71', 'A72', 'A73', 'A74', 'A75', 'A8', 'A9', 'B1', 'B2', 'B3', 'B4', 'B5']
# Soporte              : ninguno
# Justificada          : False
#
# =================================================================
# GRAFO DE ARGUMENTACION (CNL)
# =================================================================
#
# ARG A1: "Social media platforms have significant influence on public opinion", "Governments regulate other influential entities like TV networks" => "Social media platforms should be regulated by governments"
# ARG A2: "Social media can spread misinformation", "Regulation can help prevent the spread of false information" => "Social media platforms should be regulated by governments"
# ARG A3: "Social media companies prioritize profit over user safety", "Government regulation can ensure that user safety is prioritized" => "Social media platforms should be regulated by governments"
# ARG A4: "Social media has been linked to mental health issues among young people", "Regulation can address these negative impacts" => "Social media platforms should be regulated by governments"
# ARG A5: "Self-regulation by social media companies has proven insufficient", "External government oversight may be necessary" => "Social media platforms should be regulated by governments"
# ARG B1: "Social media platforms are essential for free speech and democracy" => "Social media platforms should not be regulated by governments"
# ARG B2: "Many social media users do not rely on them for critical news sources" => "Social media platforms should not be regulated by governments"
# ARG B3: "Regulation could stifle innovation and limit freedom of expression" => "Social media platforms should not be regulated by governments"
# ARG B4: "Alternative forms of media already exist and can fulfill similar roles" => "Social media platforms should not be regulated by governments"
# ARG B5: "User behavior can change without external regulation through internal policies" => "Social media platforms should not be regulated by governments"
# ARG A6: "Studies show that social media platforms have a significant impact on political engagement", "Governments regulate other influential entities like TV networks" => "Social media platforms should be regulated by governments"
# ARG A7: "Social media algorithms often amplify polarizing content which can lead to increased division", "Regulation can help mitigate this issue" => "Social media platforms should be regulated by governments"
# ARG A8: "Social media has been shown to contribute to the erosion of privacy rights", "Government intervention can protect user privacy" => "Social media platforms should be regulated by governments"
# ARG A9: "Social media companies have faced criticism for their handling of hate speech and harassment", "Regulation can provide clearer guidelines and enforcement mechanisms" => "Social media platforms should be regulated by governments"
# ARG A10: "The spread of misinformation on social media has led to real-world consequences such as vaccine hesitancy", "Regulation can help combat this problem" => "Social media platforms should be regulated by governments"
# ARG A11: "Social media's role in influencing elections and political discourse cannot be overstated", "Government oversight is necessary to maintain democratic integrity" => "Social media platforms should be regulated by governments"
# ARG A12: "Regulation can ensure that social media companies adhere to ethical standards in data collection and usage", "Ethical practices are crucial for maintaining trust in social media" => "Social media platforms should be regulated by governments"
# ARG A13: "Social media companies have a history of underreporting or misreporting the extent of their influence", "Government oversight can provide more accurate assessments" => "Social media platforms should be regulated by governments"
# ARG A14: "Regulation can help ensure that social media companies comply with international human rights laws", "Human rights compliance is important for global social media platforms" => "Social media platforms should be regulated by governments"
# ARG A15: "Social media companies often fail to adequately address the negative externalities of their services", "Regulation can internalize these costs" => "Social media platforms should be regulated by governments"
# ARG A16: "Regulation can promote transparency in how social media companies operate and make decisions", "Transparency is key to building public trust" => "Social media platforms should be regulated by governments"
# ARG A17: "Social media companies' self-regulatory measures have often been criticized for being too lenient or ineffective", "Stronger regulatory frameworks can improve accountability" => "Social media platforms should be regulated by governments"
# ARG A18: "Regulation can ensure that social media companies prioritize long-term societal benefits over short-term profits", "Balancing economic interests with social welfare is crucial" => "Social media platforms should be regulated by governments"
# ARG A19: "Social media companies have been found to manipulate user experiences to increase ad revenue", "Regulation can prevent such manipulations" => "Social media platforms should be regulated by governments"
# ARG A20: "Regulation can help ensure that social media companies respect cultural sensitivities and norms", "Cultural sensitivity is important for global reach" => "Social media platforms should be regulated by governments"
# ARG A21: "Social media companies have been accused of facilitating cyberbullying and online harassment", "Regulation can provide better protection against such behaviors" => "Social media platforms should be regulated by governments"
# ARG A22: "Regulation can ensure that social media companies take responsibility for the content they host", "Content moderation is a shared responsibility" => "Social media platforms should be regulated by governments"
# ARG A23: "Social media companies have been criticized for their lack of action against harmful content", "Regulation can enforce stricter content policies" => "Social media platforms should be regulated by governments"
# ARG A24: "Regulation can help ensure that social media companies do not engage in discriminatory practices", "Non-discrimination is a fundamental right" => "Social media platforms should be regulated by governments"
# ARG A25: "Social media companies have been found to manipulate user data for commercial gain", "Regulation can prevent such exploitation" => "Social media platforms should be regulated by governments"
# ARG A26: "Regulation can ensure that social media companies do not engage in deceptive advertising practices", "Truthful advertising is essential for consumer protection" => "Social media platforms should be regulated by governments"
# ARG A27: "Social media companies have been criticized for their failure to protect user data from breaches", "Regulation can enhance data security" => "Social media platforms should be regulated by governments"
# ARG A28: "Regulation can ensure that social media companies do not engage in anti-competitive practices", "Fair competition is vital for market stability" => "Social media platforms should be regulated by governments"
# ARG A29: "Social media companies have been found to engage in unethical business practices", "Regulation can enforce ethical conduct" => "Social media platforms should be regulated by governments"
# ARG A30: "Regulation can ensure that social media companies do not engage in environmental harm", "Environmental sustainability is becoming increasingly important" => "Social media platforms should be regulated by governments"
# ARG A31: "Social media companies have been criticized for their failure to address the digital divide", "Regulation can help bridge the gap" => "Social media platforms should be regulated by governments"
# ARG A32: "Regulation can ensure that social media companies do not engage in unfair labor practices", "Labor rights are fundamental" => "Social media platforms should be regulated by governments"
# ARG A33: "Social media companies have been found to engage in predatory pricing strategies", "Regulation can prevent such tactics" => "Social media platforms should be regulated by governments"
# ARG A34: "Regulation can ensure that social media companies do not engage in monopolistic practices", "Monopolies can stifle competition and innovation" => "Social media platforms should be regulated by governments"
# ARG A35: "Social media companies have been criticized for their failure to address the negative impacts of their services on society", "Regulation can help mitigate these effects" => "Social media platforms should be regulated by governments"
# ARG A36: "Regulation can ensure that social media companies do not engage in deceptive marketing practices", "Transparent marketing is important for consumer trust" => "Social media platforms should be regulated by governments"
# ARG A37: "Social media companies have been found to engage in unethical business practices that harm vulnerable populations", "Regulation can protect those groups" => "Social media platforms should be regulated by governments"
# ARG A38: "Social media companies have been found to engage in unethical business practices that harm vulnerable populations", "Regulation can protect those groups" => "Social media platforms should be regulated by governments"
# ARG A39: "Social media companies have been criticized for their failure to address the negative impacts of their services on society", "Regulation can help mitigate these effects" => "Social media platforms should be regulated by governments"
# ARG A40: "Regulation can ensure that social media companies do not engage in deceptive marketing practices", "Transparent marketing is important for consumer trust" => "Social media platforms should be regulated by governments"
# ARG A41: "Social media companies have been found to engage in unethical business practices", "Regulation can enforce ethical conduct" => "Social media platforms should be regulated by governments"
# ARG A42: "Regulation can ensure that social media companies do not engage in monopolistic practices", "Monopolies can stifle competition and innovation" => "Social media platforms should be regulated by governments"
# ARG A43: "Social media companies have been criticized for their failure to address the digital divide", "Regulation can help bridge the gap" => "Social media platforms should be regulated by governments"
# ARG A44: "Regulation can ensure that social media companies do not engage in unfair labor practices", "Labor rights are fundamental" => "Social media platforms should be regulated by governments"
# ARG A45: "Social media companies have been found to engage in predatory pricing strategies", "Regulation can prevent such tactics" => "Social media platforms should be regulated by governments"
# ARG A46: "Regulation can ensure that social media companies do not engage in environmental harm", "Environmental sustainability is becoming increasingly important" => "Social media platforms should be regulated by governments"
# ARG A47: "Social media companies have been criticized for their failure to protect user data from breaches", "Regulation can enhance data security" => "Social media platforms should be regulated by governments"
# ARG A48: "Regulation can ensure that social media companies do not engage in anti-competitive practices", "Fair competition is vital for market stability" => "Social media platforms should be regulated by governments"
# ARG A49: "Social media companies have been found to engage in discriminatory practices", "Regulation can ensure non-discrimination" => "Social media platforms should be regulated by governments"
# ARG A50: "Regulation can ensure that social media companies do not engage in deceptive advertising practices", "Truthful advertising is essential for consumer protection" => "Social media platforms should be regulated by governments"
# ARG A51: "Social media companies have been criticized for their lack of action against harmful content", "Regulation can enforce stricter content policies" => "Social media platforms should be regulated by governments"
# ARG A52: "Regulation can ensure that social media companies do not engage in discriminatory hiring practices", "Diversity and inclusion are important values" => "Social media platforms should be regulated by governments"
# ARG A53: "Social media companies have been found to manipulate user data for commercial gain", "Regulation can prevent such exploitation" => "Social media platforms should be regulated by governments"
# ARG A54: "Regulation can ensure that social media companies do not engage in monopolistic practices", "Monopolies can stifle competition and innovation" => "Social media platforms should be regulated by governments"
# ARG A55: "Social media companies have been criticized for their failure to address the negative impacts of their services on society", "Regulation can help mitigate these effects" => "Social media platforms should be regulated by governments"
# ARG A56: "Regulation can ensure that social media companies do not engage in deceptive marketing practices", "Transparent marketing is important for consumer trust" => "Social media platforms should be regulated by governments"
# ARG A57: "Social media companies have been found to engage in unethical business practices that harm vulnerable populations", "Regulation can protect those groups" => "Social media platforms should be regulated by governments"
# ARG A58: "Regulation can ensure that social media companies do not engage in unfair labor practices", "Labor rights are fundamental" => "Social media platforms should be regulated by governments"
# ARG A59: "Social media companies have been found to engage in predatory pricing strategies", "Regulation can prevent such tactics" => "Social media platforms should be regulated by governments"
# ARG A60: "Regulation can ensure that social media companies do not engage in environmental harm", "Environmental sustainability is becoming increasingly important" => "Social media platforms should be regulated by governments"
# ARG A61: "Social media companies have been criticized for their failure to protect user data from breaches", "Regulation can enhance data security" => "Social media platforms should be regulated by governments"
# ARG A62: "Regulation can ensure that social media companies do not engage in anti-competitive practices", "Fair competition is vital for market stability" => "Social media platforms should be regulated by governments"
# ARG A63: "Social media companies have been found to engage in discriminatory practices", "Regulation can ensure non-discrimination" => "Social media platforms should be regulated by governments"
# ARG A64: "Regulation can ensure that social media companies do not engage in deceptive advertising practices", "Truthful advertising is essential for consumer protection" => "Social media platforms should be regulated by governments"
# ARG A65: "Social media companies have been criticized for their lack of action against harmful content", "Regulation can enforce stricter content policies" => "Social media platforms should be regulated by governments"
# ARG A66: "Regulation can ensure that social media companies do not engage in discriminatory hiring practices", "Diversity and inclusion are important values" => "Social media platforms should be regulated by governments"
# ARG A67: "Social media companies have been found to manipulate user data for commercial gain", "Regulation can prevent such exploitation" => "Social media platforms should be regulated by governments"
# ARG A68: "Regulation can ensure that social media companies do not engage in monopolistic practices", "Monopolies can stifle competition and innovation" => "Social media platforms should be regulated by governments"
# ARG A69: "Regulation can ensure that social media companies do not engage in deceptive marketing practices", "Transparent marketing is important for consumer trust" => "Social media platforms should be regulated by governments"
# ARG A70: "Social media companies have been found to engage in unethical business practices that harm vulnerable populations", "Regulation can protect those groups" => "Social media platforms should be regulated by governments"
# ARG A71: "Regulation can ensure that social media companies do not engage in unfair labor practices", "Labor rights are fundamental" => "Social media platforms should be regulated by governments"
# ARG A72: "Social media companies have been found to engage in predatory pricing strategies", "Regulation can prevent such tactics" => "Social media platforms should be regulated by governments"
# ARG A73: "Regulation can ensure that social media companies do not engage in environmental harm", "Environmental sustainability is becoming increasingly important" => "Social media platforms should be regulated by governments"
# ARG A74: "Social media companies have been criticized for their failure to protect user data from breaches", "Regulation can enhance data security" => "Social media platforms should be regulated by governments"
# ARG A75: "Regulation can ensure that social media companies do not engage in anti-competitive practices", "Fair competition is vital for market stability" => "Social media platforms should be regulated by governments"
# B1 REFUTA A1
# B1 REFUTA A2
# B1 REFUTA A3
# B1 REFUTA A4
# B1 REFUTA A5
# B2 REFUTA A1
# B2 REFUTA A2
# B2 REFUTA A3
# B2 REFUTA A4
# B2 REFUTA A5
# B3 REFUTA A1
# B3 REFUTA A2
# B3 REFUTA A3
# B3 REFUTA A4
# B3 REFUTA A5
# B4 REFUTA A1
# B4 REFUTA A2
# B4 REFUTA A3
# B4 REFUTA A4
# B4 REFUTA A5
# B5 REFUTA A1
# B5 REFUTA A2
# B5 REFUTA A3
# B5 REFUTA A4
# B5 REFUTA A5
# A6 REFUTA B1
# A7 REFUTA B1
# A8 REFUTA B1
# A9 REFUTA B1
# A10 REFUTA B1
# A11 REFUTA B1
# A12 REFUTA B1
# A13 REFUTA B1
# A14 REFUTA B1
# A15 REFUTA B1
# A16 REFUTA B1
# A17 REFUTA B1
# A18 REFUTA B1
# A19 REFUTA B1
# A20 REFUTA B1
# A21 REFUTA B1
# A22 REFUTA B1
# A23 REFUTA B1
# A24 REFUTA B1
# A25 REFUTA B1
# A26 REFUTA B1
# A27 REFUTA B1
# A28 REFUTA B1
# A29 REFUTA B1
# A30 REFUTA B1
# A31 REFUTA B1
# A32 REFUTA B1
# A33 REFUTA B1
# A34 REFUTA B1
# A35 REFUTA B1
# A36 REFUTA B1
# A37 REFUTA B1
# A6 SOCAVA B1
# A7 SOCAVA B1
# A8 SOCAVA B1
# A9 SOCAVA B1
# A10 SOCAVA B1
# A11 SOCAVA B1
# A12 SOCAVA B1
# A13 SOCAVA B1
# A14 SOCAVA B1
# A15 SOCAVA B1
# A16 SOCAVA B1
# A17 SOCAVA B1
# A18 SOCAVA B1
# A19 SOCAVA B1
# A20 SOCAVA B1
# A21 SOCAVA B1
# A22 SOCAVA B1
# A23 SOCAVA B1
# A24 SOCAVA B1
# A25 SOCAVA B1
# A26 SOCAVA B1
# A27 SOCAVA B1
# A28 SOCAVA B1
# A29 SOCAVA B1
# A30 SOCAVA B1
# A31 SOCAVA B1
# A32 SOCAVA B1
# A33 SOCAVA B1
# A34 SOCAVA B1
# A35 SOCAVA B1
# A36 SOCAVA B1
# A37 SOCAVA B1
# A38 REFUTA B1
# A39 REFUTA B1
# A40 REFUTA B1
# A41 REFUTA B1
# A42 REFUTA B1
# A43 REFUTA B1
# A44 REFUTA B1
# A45 REFUTA B1
# A46 REFUTA B1
# A47 REFUTA B1
# A48 REFUTA B1
# A49 REFUTA B1
# A50 REFUTA B1
# A51 REFUTA B1
# A52 REFUTA B1
# A53 REFUTA B1
# A54 REFUTA B1
# A55 REFUTA B1
# A56 REFUTA B1
# A57 REFUTA B1
# A58 REFUTA B1
# A59 REFUTA B1
# A60 REFUTA B1
# A61 REFUTA B1
# A62 REFUTA B1
# A63 REFUTA B1
# A64 REFUTA B1
# A65 REFUTA B1
# A66 REFUTA B1
# A67 REFUTA B1
# A68 REFUTA B1
# A69 REFUTA B1
# A70 REFUTA B1
# A71 REFUTA B1
# A72 REFUTA B1
# A73 REFUTA B1
# A74 REFUTA B1
# A75 REFUTA B1
# CONCLUSION: "Social media platforms should be regulated by governments"
# Resultado guardado en: resultado_20260627_094715.json
# Archivos guardados:
#   resultado_20260627_094715.json  ->  datos estructurados (JSON)
#   informe_20260627_094715.txt  ->  informe completo (TXT, identico a lo de arriba)
#   grafo_20260627_094715.png  ->  grafo coloreado IN/OUT/UNDEC (PNG)
